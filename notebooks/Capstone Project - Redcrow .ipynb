# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics 
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz

# %%
raw_data = pd.read_csv('/Users/truptikhodke/Downloads/StartupFile_USA_Final.csv')

# %%
raw_data.head()
# Out:
#         startupName                homepage_url  \
# 0          One Inc.          http://whatis1.com
# 1       10-20 Media   http://www.10-20media.com
# 2             Redox  http://www.redoxengine.com
# 3             10sec             https://10s.ec/
# 4  10X Technologies  http://10xtechnologies.com
#
#                                        category_list  total_funding  \
# 0                                             mobile      1150050.0
# 1                                         e-commerce      2050000.0
# 2  health care|health care information technology...      4000000.0
# 3         e-commerce|mobile commerce|social commerce      1600000.0
# 4                                      biotechnology      3550000.0
#
#       status country_code state_code  funding_rounds first_funding_at  \
# 0  operating          USA         CA               3          7/20/11
# 1  operating          USA         MD               4          6/18/09
# 2  operating          USA         WI               2         11/26/14
# 3  operating          USA         CA               2         10/31/13
# 4  operating          USA         CA               2          11/7/12
#
#   last_funding_at  homepage_url_code    time_delayFor_first_round  \
# 0          2/5/14                  1  566 days 00:00:00.000000000
# 1        12/28/11                  1  285 days 00:00:00.000000000
# 2        10/20/15                  1  328 days 00:00:00.000000000
# 3          5/8/14                  1  189 days 00:00:00.000000000
# 4         1/12/15                  1  796 days 00:00:00.000000000
#
#      average_time_delay_rounds  average_raised_usd  \
# 0  465 days 12:00:00.000000000            575025.0
# 1  307 days 16:00:00.000000000            512500.0
# 2  328 days 00:00:00.000000000           2000000.0
# 3  189 days 00:00:00.000000000           1600000.0
# 4  796 days 00:00:00.000000000           1775000.0
#
#    average_time_delay_rounds_number  time_delayFor_first_round_number  \
# 0                               465                               566
# 1                               307                               285
# 2                               328                               328
# 3                               189                               189
# 4                               796                               796
#
#    No_Of_Investors MainCategory USA_Region  statusCode
# 0               12       mobile       West           1
# 1                1   e-commerce      South           0
# 2                6   healthcare    Midwest           1
# 3                2       mobile       West           1
# 4                1      biotech       West           1

# %%
print(f"The dataset contains {len(raw_data)} observations")
# Out:
# The dataset contains 9623 observations

# %%
raw_data.shape
# Out:
# (9623, 20)

# %%
raw_data.isna().sum()
# Out:
# startupName                           0
# homepage_url                        235
# category_list                         0
# total_funding                         0
# status                                0
# country_code                          0
# state_code                            0
# funding_rounds                        0
# first_funding_at                      0
# last_funding_at                       0
# homepage_url_code                     0
# time_delayFor_first_round             0
# average_time_delay_rounds             0
# average_raised_usd                    0
# average_time_delay_rounds_number      0
# time_delayFor_first_round_number      0
# No_Of_Investors                       0
# MainCategory                          0
# USA_Region                            0
# statusCode                            0
# dtype: int64

# %%
raw_data[raw_data.homepage_url.isna()]
# Out:
#                     startupName homepage_url  \
# 64             7mb Technologies          NaN
# 101          Accelerated Pharma          NaN
# 110             Accept Software          NaN
# 227             ADVANCE Medical          NaN
# 245     Advanced System Designs          NaN
# ...                         ...          ...
# 9221  Waterford Battery Systems          NaN
# 9304                        Whi          NaN
# 9335                Windtronics          NaN
# 9421                  XenSource          NaN
# 9551         ZetaRx Biosciences          NaN
#
#                                         category_list  total_funding  \
# 64                                           software      1017470.0
# 101                                   pharmaceuticals      2549999.0
# 110                        career management|software     25305000.0
# 227                                       health care     26000000.0
# 245                                          software      1325000.0
# ...                                               ...            ...
# 9221  batteries|electrical distribution|manufacturing      1594130.0
# 9304          health and wellness|health care|medical     11317850.0
# 9335                              hardware + software      4000000.0
# 9421                                         software     38000000.0
# 9551                                    biotechnology      2750000.0
#
#          status country_code state_code  funding_rounds first_funding_at  \
# 64    operating          USA         WA               3         10/28/13
# 101   operating          USA         IL               2           6/4/15
# 110    acquired          USA         CA               4          9/16/05
# 227   operating          USA         CA               2          5/31/11
# 245   operating          USA         IL               2           6/9/09
# ...         ...          ...        ...             ...              ...
# 9221  operating          USA         FL               2          3/17/14
# 9304  operating          USA         CA               2           4/2/14
# 9335  operating          USA         MI               2           4/1/09
# 9421  operating          USA         CA               3          1/13/05
# 9551  operating          USA         WA               2         12/22/10
#
#      last_funding_at  homepage_url_code    time_delayFor_first_round  \
# 64           8/14/15                  0  266 days 00:00:00.000000000
# 101         11/23/15                  0  172 days 00:00:00.000000000
# 110         12/14/10                  0  314 days 00:00:00.000000000
# 227           9/4/13                  0  827 days 00:00:00.000000000
# 245          8/17/10                  0  434 days 00:00:00.000000000
# ...              ...                ...                          ...
# 9221         7/15/15                  0  485 days 00:00:00.000000000
# 9304         4/13/15                  0  376 days 00:00:00.000000000
# 9335         1/12/10                  0  286 days 00:00:00.000000000
# 9421        10/31/06                  0  231 days 00:00:00.000000000
# 9551        12/12/12                  0  721 days 00:00:00.000000000
#
#         average_time_delay_rounds  average_raised_usd  \
# 64    327 days 12:00:00.000000000        3.391567e+05
# 101   172 days 00:00:00.000000000        1.275000e+06
# 110   638 days 08:00:00.000000000        6.326250e+06
# 227   827 days 00:00:00.000000000        1.300000e+07
# 245   434 days 00:00:00.000000000        6.625000e+05
# ...                           ...                 ...
# 9221  485 days 00:00:00.000000000        7.970650e+05
# 9304  376 days 00:00:00.000000000        5.658925e+06
# 9335  286 days 00:00:00.000000000        2.000000e+06
# 9421  328 days 00:00:00.000000000        1.266667e+07
# 9551  721 days 00:00:00.000000000        1.375000e+06
#
#       average_time_delay_rounds_number  time_delayFor_first_round_number  \
# 64                                 327                               266
# 101                                172                               172
# 110                                638                               314
# 227                                827                               827
# 245                                434                               434
# ...                                ...                               ...
# 9221                               485                               485
# 9304                               376                               376
# 9335                               286                               286
# 9421                               328                               231
# 9551                               721                               721
#
#       No_Of_Investors   MainCategory USA_Region  statusCode
# 64                  1       software       West           1
# 101                 1         pharma    Midwest           1
# 110                 3       software       West           1
# 227                 3     healthcare       West           1
# 245                 1       software    Midwest           0
# ...               ...            ...        ...         ...
# 9221                1  manufacturing      South           1
# 9304                1         pharma       West           1
# 9335                1       software    Midwest           0
# 9421                6       software       West           1
# 9551                1        biotech       West           0
#
# [235 rows x 20 columns]

# %%
#homepage_url_new mark 0 if no url else mark 1
raw_data['homepage_url_new'] = np.where(raw_data.homepage_url.isna(), 0, 1)

# %%
raw_data.head()
# Out:
#         startupName                homepage_url  \
# 0          One Inc.          http://whatis1.com
# 1       10-20 Media   http://www.10-20media.com
# 2             Redox  http://www.redoxengine.com
# 3             10sec             https://10s.ec/
# 4  10X Technologies  http://10xtechnologies.com
#
#                                        category_list  total_funding  \
# 0                                             mobile      1150050.0
# 1                                         e-commerce      2050000.0
# 2  health care|health care information technology...      4000000.0
# 3         e-commerce|mobile commerce|social commerce      1600000.0
# 4                                      biotechnology      3550000.0
#
#       status country_code state_code  funding_rounds first_funding_at  \
# 0  operating          USA         CA               3          7/20/11
# 1  operating          USA         MD               4          6/18/09
# 2  operating          USA         WI               2         11/26/14
# 3  operating          USA         CA               2         10/31/13
# 4  operating          USA         CA               2          11/7/12
#
#   last_funding_at  ...    time_delayFor_first_round  \
# 0          2/5/14  ...  566 days 00:00:00.000000000
# 1        12/28/11  ...  285 days 00:00:00.000000000
# 2        10/20/15  ...  328 days 00:00:00.000000000
# 3          5/8/14  ...  189 days 00:00:00.000000000
# 4         1/12/15  ...  796 days 00:00:00.000000000
#
#      average_time_delay_rounds average_raised_usd  \
# 0  465 days 12:00:00.000000000           575025.0
# 1  307 days 16:00:00.000000000           512500.0
# 2  328 days 00:00:00.000000000          2000000.0
# 3  189 days 00:00:00.000000000          1600000.0
# 4  796 days 00:00:00.000000000          1775000.0
#
#    average_time_delay_rounds_number  time_delayFor_first_round_number  \
# 0                               465                               566
# 1                               307                               285
# 2                               328                               328
# 3                               189                               189
# 4                               796                               796
#
#    No_Of_Investors  MainCategory USA_Region statusCode  homepage_url_new
# 0               12        mobile       West          1                 1
# 1                1    e-commerce      South          0                 1
# 2                6    healthcare    Midwest          1                 1
# 3                2        mobile       West          1                 1
# 4                1       biotech       West          1                 1
#
# [5 rows x 21 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9623 entries, 0 to 9622
# Data columns (total 21 columns):
# startupName                         9623 non-null object
# homepage_url                        9388 non-null object
# category_list                       9623 non-null object
# total_funding                       9623 non-null float64
# status                              9623 non-null object
# country_code                        9623 non-null object
# state_code                          9623 non-null object
# funding_rounds                      9623 non-null int64
# first_funding_at                    9623 non-null object
# last_funding_at                     9623 non-null object
# homepage_url_code                   9623 non-null int64
# time_delayFor_first_round           9623 non-null object
# average_time_delay_rounds           9623 non-null object
# average_raised_usd                  9623 non-null float64
# average_time_delay_rounds_number    9623 non-null int64
# time_delayFor_first_round_number    9623 non-null int64
# No_Of_Investors                     9623 non-null int64
# MainCategory                        9623 non-null object
# USA_Region                          9623 non-null object
# statusCode                          9623 non-null int64
# homepage_url_new                    9623 non-null int64
# dtypes: float64(2), int64(7), object(12)
# memory usage: 1.5+ MB

# %%
#converting to datetime
raw_data.first_funding_at = pd.to_datetime(raw_data.first_funding_at)
raw_data.last_funding_at  = pd.to_datetime(raw_data.last_funding_at )


#calculating the number of days
raw_data['TimeBetweenFirstLast']=(raw_data.last_funding_at - raw_data.first_funding_at).astype('timedelta64[D]')

# %%
raw_data.head()
# Out:
#         startupName                homepage_url  \
# 0          One Inc.          http://whatis1.com
# 1       10-20 Media   http://www.10-20media.com
# 2             Redox  http://www.redoxengine.com
# 3             10sec             https://10s.ec/
# 4  10X Technologies  http://10xtechnologies.com
#
#                                        category_list  total_funding  \
# 0                                             mobile      1150050.0
# 1                                         e-commerce      2050000.0
# 2  health care|health care information technology...      4000000.0
# 3         e-commerce|mobile commerce|social commerce      1600000.0
# 4                                      biotechnology      3550000.0
#
#       status country_code state_code  funding_rounds first_funding_at  \
# 0  operating          USA         CA               3       2011-07-20
# 1  operating          USA         MD               4       2009-06-18
# 2  operating          USA         WI               2       2014-11-26
# 3  operating          USA         CA               2       2013-10-31
# 4  operating          USA         CA               2       2012-11-07
#
#   last_funding_at  ...    average_time_delay_rounds average_raised_usd  \
# 0      2014-02-05  ...  465 days 12:00:00.000000000           575025.0
# 1      2011-12-28  ...  307 days 16:00:00.000000000           512500.0
# 2      2015-10-20  ...  328 days 00:00:00.000000000          2000000.0
# 3      2014-05-08  ...  189 days 00:00:00.000000000          1600000.0
# 4      2015-01-12  ...  796 days 00:00:00.000000000          1775000.0
#
#   average_time_delay_rounds_number  time_delayFor_first_round_number  \
# 0                              465                               566
# 1                              307                               285
# 2                              328                               328
# 3                              189                               189
# 4                              796                               796
#
#    No_Of_Investors  MainCategory  USA_Region statusCode homepage_url_new  \
# 0               12        mobile        West          1                1
# 1                1    e-commerce       South          0                1
# 2                6    healthcare     Midwest          1                1
# 3                2        mobile        West          1                1
# 4                1       biotech        West          1                1
#
#    TimeBetweenFirstLast
# 0                 931.0
# 1                 923.0
# 2                 328.0
# 3                 189.0
# 4                 796.0
#
# [5 rows x 22 columns]

# %%
#Label encoding main category list
raw_data = raw_data.astype({"MainCategory":'category'})
raw_data["category_code"] = raw_data["MainCategory"].cat.codes
raw_data.head(20)
# Out:
#                 startupName                   homepage_url  \
# 0                  One Inc.             http://whatis1.com
# 1               10-20 Media      http://www.10-20media.com
# 2                     Redox     http://www.redoxengine.com
# 3                     10sec                https://10s.ec/
# 4          10X Technologies     http://10xtechnologies.com
# 5                  121nexus        http://www.121nexus.com
# 6         1366 Technologies        http://www.1366tech.com
# 7                    15Five              http://15five.com
# 8                   1DocWay             http://1docway.com
# 9               Babyscripts  http://www.getbabyscripts.com
# 10                  1stdibs         http://www.1stdibs.com
# 11            1World Online        http://1worldonline.com
# 12  20/20 Gene Systems Inc.            http://2020gene.com
# 13                   20x200          http://www.20x200.com
# 14                   21 Inc                  https://21.co
# 15       22nd Century Group     http://www.xxiicentury.com
# 16                  23andMe             http://23andme.com
# 17                    250ok               http://250ok.com
# 18                280 North            http://280north.com
# 19                2Checkout       http://www.2checkout.com
#
#                                         category_list  total_funding  \
# 0                                              mobile      1150050.0
# 1                                          e-commerce      2050000.0
# 2   health care|health care information technology...      4000000.0
# 3          e-commerce|mobile commerce|social commerce      1600000.0
# 4                                       biotechnology      3550000.0
# 5   health diagnostics|medical devices|personaliza...       794000.0
# 6                                       manufacturing     71450000.0
# 7                                            software      3400000.0
# 8   doctors|health care|health care information te...      1700000.0
# 9                   health and wellness|mobile health      2100000.0
# 10                                         e-commerce    117000000.0
# 11  analytics|big data|enterprise software|market ...      4000000.0
# 12                   biotechnology|health diagnostics      4345427.0
# 13                     art|e-commerce|social commerce      2800000.0
# 14    big data|bitcoin|hardware + software|technology    121050000.0
# 15                                      biotechnology     15034750.0
# 16                               biotechnology|search    227049900.0
# 17                                           software       300000.0
# 18                             presentations|software       250000.0
# 19                                         e-commerce     72000000.0
#
#        status country_code state_code  funding_rounds first_funding_at  \
# 0   operating          USA         CA               3       2011-07-20
# 1   operating          USA         MD               4       2009-06-18
# 2   operating          USA         WI               2       2014-11-26
# 3   operating          USA         CA               2       2013-10-31
# 4   operating          USA         CA               2       2012-11-07
# 5   operating          USA         RI               6       2012-02-06
# 6   operating          USA         MA               9       2008-03-27
# 7   operating          USA         CA               3       2012-01-01
# 8    acquired          USA         NY               2       2011-08-10
# 9   operating          USA         DC               3       2013-03-11
# 10  operating          USA         NY               5       2011-11-03
# 11  operating          USA         CA               3       2013-07-02
# 12  operating          USA         MD               3       2012-09-25
# 13  operating          USA         NY               2       2009-10-01
# 14  operating          USA         CA               2       2013-11-17
# 15        ipo          USA         NY               6       2010-12-28
# 16  operating          USA         CA               8       2005-11-02
# 17  operating          USA         IN               2       2012-09-01
# 18   acquired          USA         CA               2       2008-01-01
# 19  operating          USA         OH               2       2014-07-16
#
#    last_funding_at  ...  average_raised_usd average_time_delay_rounds_number  \
# 0       2014-02-05  ...        5.750250e+05                              465
# 1       2011-12-28  ...        5.125000e+05                              307
# 2       2015-10-20  ...        2.000000e+06                              328
# 3       2014-05-08  ...        1.600000e+06                              189
# 4       2015-01-12  ...        1.775000e+06                              796
# 5       2014-01-01  ...        1.323333e+05                              139
# 6       2015-04-09  ...        7.938889e+06                              321
# 7       2014-10-02  ...        1.133333e+06                              502
# 8       2015-07-21  ...        1.700000e+06                             1441
# 9       2015-04-10  ...        7.000000e+05                              380
# 10      2015-09-09  ...        3.900000e+07                              351
# 11      2015-08-13  ...        1.333333e+06                              386
# 12      2015-10-30  ...        1.448476e+06                              565
# 13      2010-08-01  ...        1.400000e+06                              304
# 14      2015-03-10  ...        6.052500e+07                              478
# 15      2014-09-18  ...        2.505792e+06                              272
# 16      2015-07-03  ...        2.838124e+07                              504
# 17      2014-03-01  ...        1.500000e+05                              546
# 18      2008-03-01  ...        2.500000e+05                               60
# 19      2015-09-15  ...        3.600000e+07                              426
#
#    time_delayFor_first_round_number  No_Of_Investors   MainCategory  \
# 0                               566               12         mobile
# 1                               285                1     e-commerce
# 2                               328                6     healthcare
# 3                               189                2         mobile
# 4                               796                1        biotech
# 5                                74                6    medicalGear
# 6                               678                9  manufacturing
# 7                               380               14       software
# 8                              1441               12     healthcare
# 9                               287                4     healthcare
# 10                              333                6     e-commerce
# 11                              152                6         mobile
# 12                             1093                1     healthcare
# 13                              304               11     e-commerce
# 14                              478               10       software
# 15                              365                1        biotech
# 16                              700               17        biotech
# 17                              546                1       software
# 18                               60                4       software
# 19                              426                3     e-commerce
#
#     USA_Region  statusCode homepage_url_new TimeBetweenFirstLast  \
# 0         West           1                1                931.0
# 1        South           0                1                923.0
# 2      Midwest           1                1                328.0
# 3         West           1                1                189.0
# 4         West           1                1                796.0
# 5    Northeast           1                1                695.0
# 6    Northeast           1                1               2569.0
# 7         West           1                1               1005.0
# 8    Northeast           1                1               1441.0
# 9        South           1                1                760.0
# 10   Northeast           1                1               1406.0
# 11        West           1                1                772.0
# 12       South           1                1               1130.0
# 13   Northeast           0                1                304.0
# 14        West           1                1                478.0
# 15   Northeast           1                1               1360.0
# 16        West           1                1               3530.0
# 17     Midwest           1                1                546.0
# 18        West           1                1                 60.0
# 19     Midwest           1                1                426.0
#
#     category_code
# 0               6
# 1               1
# 2               3
# 3               6
# 4               0
# 5               5
# 6               4
# 7               8
# 8               3
# 9               3
# 10              1
# 11              6
# 12              3
# 13              1
# 14              8
# 15              0
# 16              0
# 17              8
# 18              8
# 19              1
#
# [20 rows x 23 columns]

# %%
# Plotting the distribution of numerical and boolean categories
raw_data.hist(figsize=(30,30));

# %%
raw_data.head()
# Out:
#         startupName                homepage_url  \
# 0          One Inc.          http://whatis1.com
# 1       10-20 Media   http://www.10-20media.com
# 2             Redox  http://www.redoxengine.com
# 3             10sec             https://10s.ec/
# 4  10X Technologies  http://10xtechnologies.com
#
#                                        category_list  total_funding  \
# 0                                             mobile      1150050.0
# 1                                         e-commerce      2050000.0
# 2  health care|health care information technology...      4000000.0
# 3         e-commerce|mobile commerce|social commerce      1600000.0
# 4                                      biotechnology      3550000.0
#
#       status country_code state_code  funding_rounds first_funding_at  \
# 0  operating          USA         CA               3       2011-07-20
# 1  operating          USA         MD               4       2009-06-18
# 2  operating          USA         WI               2       2014-11-26
# 3  operating          USA         CA               2       2013-10-31
# 4  operating          USA         CA               2       2012-11-07
#
#   last_funding_at  ...  average_raised_usd average_time_delay_rounds_number  \
# 0      2014-02-05  ...            575025.0                              465
# 1      2011-12-28  ...            512500.0                              307
# 2      2015-10-20  ...           2000000.0                              328
# 3      2014-05-08  ...           1600000.0                              189
# 4      2015-01-12  ...           1775000.0                              796
#
#   time_delayFor_first_round_number  No_Of_Investors  MainCategory  USA_Region  \
# 0                              566               12        mobile        West
# 1                              285                1    e-commerce       South
# 2                              328                6    healthcare     Midwest
# 3                              189                2        mobile        West
# 4                              796                1       biotech        West
#
#    statusCode homepage_url_new TimeBetweenFirstLast  category_code
# 0           1                1                931.0              6
# 1           0                1                923.0              1
# 2           1                1                328.0              3
# 3           1                1                189.0              6
# 4           1                1                796.0              0
#
# [5 rows x 23 columns]

# %%
#Label encoding USA region 
raw_data = raw_data.astype({"USA_Region":'category'})
raw_data["USARegion_code"] = raw_data["USA_Region"].cat.codes
raw_data.head()
# Out:
#         startupName                homepage_url  \
# 0          One Inc.          http://whatis1.com
# 1       10-20 Media   http://www.10-20media.com
# 2             Redox  http://www.redoxengine.com
# 3             10sec             https://10s.ec/
# 4  10X Technologies  http://10xtechnologies.com
#
#                                        category_list  total_funding  \
# 0                                             mobile      1150050.0
# 1                                         e-commerce      2050000.0
# 2  health care|health care information technology...      4000000.0
# 3         e-commerce|mobile commerce|social commerce      1600000.0
# 4                                      biotechnology      3550000.0
#
#       status country_code state_code  funding_rounds first_funding_at  \
# 0  operating          USA         CA               3       2011-07-20
# 1  operating          USA         MD               4       2009-06-18
# 2  operating          USA         WI               2       2014-11-26
# 3  operating          USA         CA               2       2013-10-31
# 4  operating          USA         CA               2       2012-11-07
#
#   last_funding_at  ...  average_time_delay_rounds_number  \
# 0      2014-02-05  ...                               465
# 1      2011-12-28  ...                               307
# 2      2015-10-20  ...                               328
# 3      2014-05-08  ...                               189
# 4      2015-01-12  ...                               796
#
#   time_delayFor_first_round_number No_Of_Investors  MainCategory  USA_Region  \
# 0                              566              12        mobile        West
# 1                              285               1    e-commerce       South
# 2                              328               6    healthcare     Midwest
# 3                              189               2        mobile        West
# 4                              796               1       biotech        West
#
#    statusCode  homepage_url_new TimeBetweenFirstLast category_code  \
# 0           1                 1                931.0             6
# 1           0                 1                923.0             1
# 2           1                 1                328.0             3
# 3           1                 1                189.0             6
# 4           1                 1                796.0             0
#
#    USARegion_code
# 0               3
# 1               2
# 2               0
# 3               3
# 4               3
#
# [5 rows x 24 columns]

# %%
cleandf = raw_data.drop(columns = ['startupName','homepage_url','category_list','status','country_code','time_delayFor_first_round',
                    'state_code','first_funding_at','last_funding_at','homepage_url_new','MainCategory','USA_Region',
                        'average_time_delay_rounds'])

# %%
cleandf.head()
# Out:
#    total_funding  funding_rounds  homepage_url_code  average_raised_usd  \
# 0      1150050.0               3                  1            575025.0
# 1      2050000.0               4                  1            512500.0
# 2      4000000.0               2                  1           2000000.0
# 3      1600000.0               2                  1           1600000.0
# 4      3550000.0               2                  1           1775000.0
#
#    average_time_delay_rounds_number  time_delayFor_first_round_number  \
# 0                               465                               566
# 1                               307                               285
# 2                               328                               328
# 3                               189                               189
# 4                               796                               796
#
#    No_Of_Investors  statusCode  TimeBetweenFirstLast  category_code  \
# 0               12           1                 931.0              6
# 1                1           0                 923.0              1
# 2                6           1                 328.0              3
# 3                2           1                 189.0              6
# 4                1           1                 796.0              0
#
#    USARegion_code
# 0               3
# 1               2
# 2               0
# 3               3
# 4               3

# %%
# Calculating the correlation matrix
corr = cleandf.corr()
# Generating a heatmap
sns.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns)

#As it can be seen from the plot that the predictor variables do not show high multicolinearity

# %%
#split dataset in features and target variable

y = cleandf.statusCode # Target variable
x = cleandf[[ 'total_funding', 'funding_rounds','homepage_url_code','average_raised_usd','average_time_delay_rounds_number',
            'time_delayFor_first_round_number','No_Of_Investors','category_code','TimeBetweenFirstLast','USARegion_code']]

# %%
cleandf.statusCode.value_counts()
# Out:
# 1    7204
# 0    2419
# Name: statusCode, dtype: int64

# %%
target_count = cleandf.statusCode.value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

target_count.plot(kind='bar', title='Count (target)');
# Out:
# Class 0: 2419
# Class 1: 7204
# Proportion: 0.34 : 1

# %%
from pprint import pprint
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %%
def split_downsample(X,Y):
    var= y.name
    #split data into test and training sets
    X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33)
    #combine them back for resampling
    train_data = pd.concat([X_train, y_train], axis=1)
    # separate minority and majority classes
    negative = train_data[train_data[var]==0]
    positive = train_data[train_data[var]==1]

    # downsample majority
    neg_downsampled = resample(negative,
        replace=True, # sample with replacement
        n_samples=len(positive), # match number in minority class
        ) # reproducible results
    
    
    # combine majority and upsampled minority
    upsampled = pd.concat([neg_downsampled, positive])
    # check new class counts
    
    new_X_train = upsampled.drop(var,axis=1)
    new_y_train = upsampled[var]
    
    return new_X_train, X_test, new_y_train, y_test

# %%
def downsample(X,y,rs=None):
    var= y.name
    
    joint = pd.concat([X, y], axis=1)
    negative = joint[joint[var]==0]
    positive = joint[joint[var]==1]

    # downsample majority
    neg_downsampled = resample(negative,
        replace=True, # sample with replacement
        n_samples=len(positive), # match number in minority class
        random_state = rs) # reproducible results
    
    
    # combine majority and upsampled minority
    upsampled = pd.concat([neg_downsampled, positive])
    # check new class counts
    
    new_X = upsampled.drop(var,axis=1)
    new_y = upsampled[var]
    
    return new_X, new_y

# %%
downsample(x, y)[1].value_counts()
# Out:
# 1    7204
# 0    7204
# Name: statusCode, dtype: int64

# %%
target_count = downsample(x, y)[1].value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

target_count.plot(kind='bar', title='Count (target)');
# Out:
# Class 0: 7204
# Class 1: 7204
# Proportion: 1.0 : 1

# %%
def downsample_split(X,y):
    var= y.name
    #combine them for resampling
    train_data = pd.concat([X, y], axis=1)
    # separate minority and majority classes
    negative = train_data[train_data[var]==0]
    positive = train_data[train_data[var]==1]

    # downsample majority
    neg_downsampled = resample(negative,
        replace=True, # sample with replacement
        n_samples=len(positive), # match number in minority class
        ) # reproducible results
    
    
    # combine majority and upsampled minority
    upsampled = pd.concat([neg_downsampled, positive])
    
    X_train, X_test, y_train, y_test = train_test_split( 
        upsampled.drop(var,axis=1), upsampled[var], stratify=upsampled[var],
        test_size=0.33,)
    
    # check new class counts
#     print(y_train.value_counts())

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = downsample_split(x,y)

# %%
# #splitting the dataset into train and test

# x_train , x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
#Scaling the independent variables

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import RandomOverSampler

sampler = RandomOverSampler(random_state=0)

X_rs, y_rs = sampler.fit_sample(X_train, y_train)

# %%
#Building the decision tree
classifier = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5)
classifier.fit(X_rs, y_rs)

# %%
#make predictions on the test data
y_pred = classifier.predict(X_test)

# %%
#Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm

# %%
# Accuracy of the model
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
#support vector machine


from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score




def pred_models_scaled(X_train, y_train, X_test, y_test):
    logreg = LogisticRegression()
    svm_model = svm.SVC()
    rf = RandomForestClassifier()

    l = logreg.fit(X_train,y_train)
    s = svm_model.fit(X_train,y_train)
    r = rf.fit(X_train,y_train)
   
    l_pred = l.predict(X_test)
    s_pred = s.predict(X_test)
    r_pred = r.predict(X_test)
    
    acc_scl= {'model':['logreg','svc','rf'], 
              'tst_scr':[accuracy_score(y_test,l_pred),accuracy_score(y_test,s_pred),accuracy_score(y_test,r_pred)],
            'trn_acc':[accuracy_score(y_train, l.predict(X_train)),accuracy_score(y_train, s.predict(X_train)),
                       accuracy_score(y_train, r.predict(X_train))]}
                                                                                    
    acc_scl = pd.DataFrame(data= acc_scl)
    
    return acc_scl


scl = pred_models_scaled(X_train,y_train,X_test,y_test)
scl
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#     model   tst_scr   trn_acc
# 0  logreg  0.619138  0.622294
# 1     svc  0.645005  0.649953
# 2      rf  0.824185  0.992230

# %%
print("Random Forest", sep=('\n'))
print(pd.crosstab(y_test, r_pred, rownames=['Actual Observation'], colnames=['Predicted Observation']))
from sklearn.metrics import classification_report
print(classification_report(y_test, r_pred))
print("")
print("Accuracy:", metrics.accuracy_score(y_test, r_pred))
# Out:
# Random Forest
# Predicted Observation     0     1
# Actual Observation
# 0                      2189   188
# 1                       680  1698
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83      2377
#            1       0.90      0.71      0.80      2378
#
#     accuracy                           0.82      4755
#    macro avg       0.83      0.82      0.82      4755
# weighted avg       0.83      0.82      0.82      4755
#
#
# Accuracy: 0.8174553101997897

# %%
##Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Fitting Random Forest Classification to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 42)
classifier.fit(X_rs, y_rs)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
print("Random Forest", sep=('\n'))
print(pd.crosstab(y_test, y_pred, rownames=['Actual Observation'], colnames=['Predicted Observation']))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
print("")
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Random Forest
# Predicted Observation     0     1
# Actual Observation
# 0                      2174   204
# 1                       648  1729
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84      2378
#            1       0.89      0.73      0.80      2377
#
#     accuracy                           0.82      4755
#    macro avg       0.83      0.82      0.82      4755
# weighted avg       0.83      0.82      0.82      4755
#
#
# Accuracy: 0.820820189274448

# %%
##Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
model=GradientBoostingClassifier()
model.fit(X_rs, y_rs)
y_pred=model.predict(X_test)


print("Gradient Boosting", sep=('\n'))
print(pd.crosstab(y_test, y_pred, rownames=['Actual Observation'], 
                  colnames=['Predicted Observation']))

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
print("")
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Gradient Boosting
# Predicted Observation     0     1
# Actual Observation
# 0                      1754   624
# 1                       891  1486
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70      2378
#            1       0.70      0.63      0.66      2377
#
#     accuracy                           0.68      4755
#    macro avg       0.68      0.68      0.68      4755
# weighted avg       0.68      0.68      0.68      4755
#
#
# Accuracy: 0.6813880126182965

# %%
# Import the classifiers
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import roc_curve, roc_auc_score

# Instantiate the classfiers and make a list
classifiers = [DecisionTreeClassifier(random_state=1234),
               RandomForestClassifier(random_state=1234),
          GradientBoostingClassifier(random_state=1234)]

 


# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    model = cls.fit(X_rs, y_rs)
    yproba = model.predict_proba(X_test)[::,1]
    
    fpr, tpr, _ = roc_curve(y_test,  yproba)
    auc = roc_auc_score(y_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)

# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)


fig = plt.figure(figsize=(8,6))

for i in result_table.index:
    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             label="{}, AUC={:.3f}".format(i, result_table.loc[i]['auc']))
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("Flase Positive Rate", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("True Positive Rate", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

plt.show()
